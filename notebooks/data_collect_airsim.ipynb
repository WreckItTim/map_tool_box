# %%
from map_tool_box.modules import Data_Map
from map_tool_box.modules import Utils
from pathlib import Path

# %% [markdown]
# # set params

# %%
map_name = 'AirSimNH'
sensor_name = 'DepthV1'

# write json file with info about this sensor for future access
info = {
  "notes": "forward facing 2D depth map", # can be anything here for future users
  "visualization_type":"grey-image", # key-word that indicaets how to display this image -- checkout Data_Map.animate() code
  "obs_type": "array", # data-type of object -- likely array
  "array_size": [ # if it is an array, then this specifies the dimensions
    1,
    144,
    256
  ]
}

# %% [markdown]
# # write meta data for later access

# %%
# this maps all of the data to the different data_dict file parts for future data fetches
Data_Map.write_meta_data(map_name, sensor_name)

# this writes the json info file set during params at top of this notebook
#Data_Map.write_sensor_info(map_name, sensor_name, info)
